# %% [markdown]
# # $${\color{Orange}Databricks\ Basics\ Usecase 1}$$
# ###### Description: Learnig Databricks Notebooks **Fundamentals**

# %% [markdown]
# ####Learn Mark Down Command

# %% [markdown]
# - Creating Headings and Sub-headings using # (maximum 6 levels of sub-headings can be added by adding the no. of #'s to 6)
# - How to **Bold** a text
# - How to *Italic* a text
# - Insert URL using **\[URL Label](url)** command: [Image URL](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQjHkPO9BNRX0bjAo1Q9J7sJWVrdFm_ddlP7Q&s)
# - Insert Image directly from URL using **\!\[](url)** command
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQjHkPO9BNRX0bjAo1Q9J7sJWVrdFm_ddlP7Q&s)

# %% [markdown]
# ####Create Volume using %sql command

# %%
# %sql
create volume if not exists workspace.default.usage_metrics;

# %% [markdown]
# ####Check if volume if created using %fs command

# %%
# %fs ls "dbfs:///Volumes/workspace/default/usage_metrics"

# %%
# %fs ls "/Volumes/workspace/default/usage_metrics"

# %%
# %run
