# %% [markdown]
# #####Dataframes

# %%
from pyspark.sql.session import SparkSession
print(spark)
spark1 = SparkSession.builder.getOrCreate()
print(spark1)

# %%
df = spark.read.csv("dbfs:/Volumes/workspace/default/volumewe47_datalake/patients.csv",header=True)
display(df) #display is databrick addition/property to spark, its not available in traditional Apache spark

# %%
#DSL
df.where('married = "Yes"').show()
df.where('married = "Yes"').write.saveAsTable("default.patients_married") #create a table: patients_married in default catalog's datalake house

# %%
spark.sql("select * from patients_married").limit(7).show()
