# %% [markdown]
# #Solution: 1_Usecase_Explore_Notebooks_magic_commands

# %% [markdown]
# ####Task1: <b>This is <i>solution</i> of magic commands usecase</b>
# $${\color{Green}Rizwan}$$
#
# ![](https://fpimages.withfloats.com/actual/6936e213e40c3ddda3969dd0.jpeg%22)

# %% [markdown]
# ####Task2: Create Volume

# %%
# %sql create volume if not exists usage_metrics

# %%
import requests
read_date_from_table = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv").text
print(read_date_from_table)
#dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv", read_date_from_table, True)
