# %% [markdown]
# #1_Explore_Notebooks_Magic_Commands

# %% [markdown]
# ###How to add Logo from a url
# ![](https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png)

# %%
# %sh ls -ltr
#df -kh
du -ha ./
#du --help

# %% [markdown]
# ######Create Volume in Catalog

# %%
# %sql CREATE VOLUME IF NOT EXISTS workspace.default.volumewe47_datalake;

# %%
# %fs ls "/Volumes/workspace/default/volumewe47_datalake"

# %%
# %fs head "dbfs:/Volumes/workspace/default/volumewe47_datalake/custs"

# %%
# %fs cp "/Volumes/workspace/default/volumewe47_datalake/custs" "/Volumes/workspace/default/volumewe47_datalake/custs_copy"

# %%
# %python
dbutils.fs.cp("/Volumes/workspace/default/volumewe47_datalake/custs_copy", "/Volumes/workspace/default/volumewe47_datalake/custs_copy2")

# %%
# %fs ls "/Volumes/workspace/default/volumewe47_datalake/"

# %%
# %sql
create table if not exists cities(id int, name string);
insert into cities values(1,'A'),(2,'B');
select * from cities;

# %%
# %run "/Workspace/Users/riz.ahmed003@gmail.com/ra_de_workspace/4_child_notebook"
